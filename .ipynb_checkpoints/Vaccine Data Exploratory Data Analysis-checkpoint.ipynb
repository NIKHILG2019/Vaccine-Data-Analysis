# %%
import pandas as pd

# %%
df_vaers_data = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2021VAERSDATA.csv')
df_vaers_symptoms = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2021VAERSSYMPTOMS.csv')
df_vaers_vax = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2021VAERSVAX.csv')
# Out:
# C:\Users\NIKHIL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,12,15,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_vaers_data
# Out:
#         VAERS_ID  RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0         916600  1/1/2021    TX     33.0     33.0      NaN   F      NaN
# 1         916601  1/1/2021    CA     73.0     73.0      NaN   F      NaN
# 2         916602  1/1/2021    WA     23.0     23.0      NaN   F      NaN
# 3         916603  1/1/2021    WA     58.0     58.0      NaN   F      NaN
# 4         916604  1/1/2021    TX     47.0     47.0      NaN   F      NaN
# ...          ...       ...   ...      ...      ...      ...  ..      ...
# 537957   1669586  9/3/2021   NaN      NaN      NaN      NaN   F      NaN
# 537958   1669590  9/3/2021   NaN      NaN      NaN      NaN   F      NaN
# 537959   1669625  9/3/2021    MD     18.0     18.0      NaN   F      NaN
# 537960   1669875  9/3/2021    MN     36.0     36.0      NaN   F      NaN
# 537961   1669883  9/3/2021    FL     32.0     32.0      NaN   M      NaN
#
#                                              SYMPTOM_TEXT DIED  ...  \
# ...

# %%
df_vaers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537962 entries, 0 to 537961
# Data columns (total 35 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   VAERS_ID      537962 non-null  int64
#  1   RECVDATE      537962 non-null  object
#  2   STATE         473865 non-null  object
#  3   AGE_YRS       484162 non-null  float64
#  4   CAGE_YR       440430 non-null  float64
#  5   CAGE_MO       1555 non-null    float64
#  6   SEX           537962 non-null  object
#  7   RPT_DATE      350 non-null     object
#  8   SYMPTOM_TEXT  537838 non-null  object
#  9   DIED          6771 non-null    object
#  10  DATEDIED      6096 non-null    object
#  11  L_THREAT      8451 non-null    object
#  12  ER_VISIT      52 non-null      object
#  13  HOSPITAL      31129 non-null   object
#  14  HOSPDAYS      21343 non-null   float64
#  15  X_STAY        298 non-null     object
#  16  DISABLE       8245 non-null    object
# ...

# %%
df_vaers_symptoms
# Out:
#         VAERS_ID                 SYMPTOM1  SYMPTOMVERSION1  \
# 0         916600                Dysphagia             23.1
# 1         916601                  Anxiety             23.1
# 2         916602         Chest discomfort             23.1
# 3         916603                Dizziness             23.1
# 4         916604  Injection site erythema             23.1
# ...          ...                      ...              ...
# 717150   1669875             Chemotherapy             24.0
# 717151   1669875         Myelosuppression             24.0
# 717152   1669875         Premature labour             24.0
# 717153   1669883        Basedow's disease             24.0
# 717154   1669883     Heart rate decreased             24.0
#
#                           SYMPTOM2  SYMPTOMVERSION2  \
# 0                     Epiglottitis             23.1
# 1                         Dyspnoea             23.1
# 2                        Dysphagia             23.1
# ...

# %%
df_vaers_symptoms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717155 entries, 0 to 717154
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         717155 non-null  int64
#  1   SYMPTOM1         717155 non-null  object
#  2   SYMPTOMVERSION1  717155 non-null  float64
#  3   SYMPTOM2         564019 non-null  object
#  4   SYMPTOMVERSION2  564019 non-null  float64
#  5   SYMPTOM3         437120 non-null  object
#  6   SYMPTOMVERSION3  437120 non-null  float64
#  7   SYMPTOM4         330578 non-null  object
#  8   SYMPTOMVERSION4  330578 non-null  float64
#  9   SYMPTOM5         244504 non-null  object
#  10  SYMPTOMVERSION5  244504 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 60.2+ MB

# %%
df_vaers_vax
# Out:
#         VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0         916600  COVID19          MODERNA  037K20A               1        IM
# 1         916601  COVID19          MODERNA  025L20A               1        IM
# 2         916602  COVID19  PFIZER\BIONTECH   EL1284               1        IM
# 3         916603  COVID19          MODERNA  unknown             UNK       NaN
# 4         916604  COVID19          MODERNA      NaN               1        IM
# ...          ...      ...              ...      ...             ...       ...
# 560331   1669586  COVID19          JANSSEN      NaN             UNK       NaN
# 560332   1669590  COVID19          JANSSEN  Unknown             UNK       NaN
# 560333   1669625  COVID19          MODERNA   0UU21A               1        OT
# 560334   1669875  COVID19  PFIZER\BIONTECH   EW0167               1        IM
# 560335   1669883  COVID19  PFIZER\BIONTECH   FD8448               1        IM
#
# ...

# %%
df_vaers_vax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560336 entries, 0 to 560335
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         560336 non-null  int64
#  1   VAX_TYPE         560336 non-null  object
#  2   VAX_MANU         560336 non-null  object
#  3   VAX_LOT          387484 non-null  object
#  4   VAX_DOSE_SERIES  557980 non-null  object
#  5   VAX_ROUTE        440266 non-null  object
#  6   VAX_SITE         417434 non-null  object
#  7   VAX_NAME         560336 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 34.2+ MB

# %%
df_merge_vaers = pd.merge(left=df_vaers_data,right=df_vaers_symptoms,on='VAERS_ID')
df_merge_vaers = pd.merge(left=df_merge_vaers,right=df_vaers_vax,on='VAERS_ID')
df_merge_vaers
# Out:
#         VAERS_ID  RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0         916600  1/1/2021    TX     33.0     33.0      NaN   F      NaN
# 1         916601  1/1/2021    CA     73.0     73.0      NaN   F      NaN
# 2         916602  1/1/2021    WA     23.0     23.0      NaN   F      NaN
# 3         916603  1/1/2021    WA     58.0     58.0      NaN   F      NaN
# 4         916604  1/1/2021    TX     47.0     47.0      NaN   F      NaN
# ...          ...       ...   ...      ...      ...      ...  ..      ...
# 751015   1669875  9/3/2021    MN     36.0     36.0      NaN   F      NaN
# 751016   1669875  9/3/2021    MN     36.0     36.0      NaN   F      NaN
# 751017   1669875  9/3/2021    MN     36.0     36.0      NaN   F      NaN
# 751018   1669883  9/3/2021    FL     32.0     32.0      NaN   M      NaN
# 751019   1669883  9/3/2021    FL     32.0     32.0      NaN   M      NaN
#
#                                              SYMPTOM_TEXT DIED  ...  \
# ...

# %%
df_merge_vaers.shape
# Out:
# (751020, 52)

# %%
df_merge_vaers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 751020 entries, 0 to 751019
# Data columns (total 52 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         751020 non-null  int64
#  1   RECVDATE         751020 non-null  object
#  2   STATE            672316 non-null  object
#  3   AGE_YRS          688178 non-null  float64
#  4   CAGE_YR          626123 non-null  float64
#  5   CAGE_MO          3032 non-null    float64
#  6   SEX              751020 non-null  object
#  7   RPT_DATE         490 non-null     object
#  8   SYMPTOM_TEXT     750888 non-null  object
#  9   DIED             11859 non-null   object
#  10  DATEDIED         10998 non-null   object
#  11  L_THREAT         19419 non-null   object
#  12  ER_VISIT         79 non-null      object
#  13  HOSPITAL         68606 non-null   object
#  14  HOSPDAYS         50062 non-null   float64
#  15  X_STAY           593 non-null     object
# ...

# %%
df_merge_vaers.head()
# Out:
#    VAERS_ID  RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916600  1/1/2021    TX     33.0     33.0      NaN   F      NaN
# 1    916601  1/1/2021    CA     73.0     73.0      NaN   F      NaN
# 2    916602  1/1/2021    WA     23.0     23.0      NaN   F      NaN
# 3    916603  1/1/2021    WA     58.0     58.0      NaN   F      NaN
# 4    916604  1/1/2021    TX     47.0     47.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Right side of epiglottis swelled up and hinder...  NaN  ...
# 1  Approximately 30 min post vaccination administ...  NaN  ...
# 2  About 15 minutes after receiving the vaccine, ...  NaN  ...
# 3  extreme fatigue, dizziness,. could not lift my...  NaN  ...
# 4  Injection site swelling, redness, warm to the ...  NaN  ...
#
#   SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5 VAX_TYPE         VAX_MANU  VAX_LOT  \
# 0             NaN      NaN             NaN  COVID19          MODERNA  037K20A
# ...

# %%
df_merge_vaers.tail()
# Out:
#         VAERS_ID  RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 751015   1669875  9/3/2021    MN     36.0     36.0      NaN   F      NaN
# 751016   1669875  9/3/2021    MN     36.0     36.0      NaN   F      NaN
# 751017   1669875  9/3/2021    MN     36.0     36.0      NaN   F      NaN
# 751018   1669883  9/3/2021    FL     32.0     32.0      NaN   M      NaN
# 751019   1669883  9/3/2021    FL     32.0     32.0      NaN   M      NaN
#
#                                              SYMPTOM_TEXT DIED  ...  \
# 751015  Pregnancy history: G2P1001. Patient had the Pf...    Y  ...
# 751016  Pregnancy history: G2P1001. Patient had the Pf...    Y  ...
# 751017  Pregnancy history: G2P1001. Patient had the Pf...    Y  ...
# 751018  Systemic: Cardiac Disorder (diagnosed by MD)-S...  NaN  ...
# 751019  Systemic: Cardiac Disorder (diagnosed by MD)-S...  NaN  ...
#
#        SYMPTOMVERSION4                  SYMPTOM5 SYMPTOMVERSION5 VAX_TYPE  \
# ...
