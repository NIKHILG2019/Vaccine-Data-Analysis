# %%
import pandas as pd

# %%
df_vaers_data = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2021VAERSDATA.csv')
df_vaers_symptoms = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2021VAERSSYMPTOMS.csv')
df_vaers_vax = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2021VAERSVAX.csv')
df_vaers_data_2020 = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2020VAERSDATA.csv')
df_vaers_symptoms_2020 = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2020VAERSSYMPTOMS.csv')
df_vaers_vax_2020 = pd.read_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\2020VAERSVAX.csv')
df_vaers_data = pd.concat([df_vaers_data,df_vaers_data_2020],axis=0)
df_vaers_symptoms = pd.concat([df_vaers_symptoms,df_vaers_symptoms_2020],axis=0)
df_vaers_vax = pd.concat([df_vaers_vax,df_vaers_vax_2020],axis=0)
# Out:
# C:\Users\NIKHIL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,12,15,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\NIKHIL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,12,15,23,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_vaers_data
# Out:
#        VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0        916600    1/1/2021    TX     33.0     33.0      NaN   F      NaN
# 1        916601    1/1/2021    CA     73.0     73.0      NaN   F      NaN
# 2        916602    1/1/2021    WA     23.0     23.0      NaN   F      NaN
# 3        916603    1/1/2021    WA     58.0     58.0      NaN   F      NaN
# 4        916604    1/1/2021    TX     47.0     47.0      NaN   F      NaN
# ...         ...         ...   ...      ...      ...      ...  ..      ...
# 50140    918441  12/31/2020    NE     35.0     35.0      NaN   F      NaN
# 50141    918442  12/31/2020    AR      NaN     34.0      NaN   F      NaN
# 50142    918503  12/31/2020    RI     50.0     50.0      NaN   F      NaN
# 50143    918512  12/31/2020    OR      1.0      1.0      0.0   M      NaN
# 50144    918561  12/31/2020    WA     95.0     95.0      NaN   F      NaN
#
#                                             SYMPTOM_TEXT DIED  ...  \
# ...

# %%
df_vaers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588107 entries, 0 to 50144
# Data columns (total 35 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   VAERS_ID      588107 non-null  int64
#  1   RECVDATE      588107 non-null  object
#  2   STATE         517073 non-null  object
#  3   AGE_YRS       522691 non-null  float64
#  4   CAGE_YR       477382 non-null  float64
#  5   CAGE_MO       4509 non-null    float64
#  6   SEX           588107 non-null  object
#  7   RPT_DATE      1354 non-null    object
#  8   SYMPTOM_TEXT  587977 non-null  object
#  9   DIED          6938 non-null    object
#  10  DATEDIED      6190 non-null    object
#  11  L_THREAT      8766 non-null    object
#  12  ER_VISIT      226 non-null     object
#  13  HOSPITAL      32722 non-null   object
#  14  HOSPDAYS      22026 non-null   float64
#  15  X_STAY        327 non-null     object
#  16  DISABLE       9175 non-null    object
# ...

# %%
df_vaers_symptoms
# Out:
#        VAERS_ID                   SYMPTOM1  SYMPTOMVERSION1  \
# 0        916600                  Dysphagia             23.1
# 1        916601                    Anxiety             23.1
# 2        916602           Chest discomfort             23.1
# 3        916603                  Dizziness             23.1
# 4        916604    Injection site erythema             23.1
# ...         ...                        ...              ...
# 61495    918441        Injection site pain             23.1
# 61496    918442                 Arthralgia             23.1
# 61497    918503           Chest discomfort             23.1
# 61498    918512  Injection site induration             24.0
# 61499    918561       Blood glucose normal             23.1
#
#                       SYMPTOM2  SYMPTOMVERSION2                  SYMPTOM3  \
# 0                 Epiglottitis             23.1                       NaN
# 1                     Dyspnoea             23.1                       NaN
# ...

# %%
df_vaers_symptoms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 778655 entries, 0 to 61499
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         778655 non-null  int64
#  1   SYMPTOM1         778655 non-null  object
#  2   SYMPTOMVERSION1  778655 non-null  float64
#  3   SYMPTOM2         611032 non-null  object
#  4   SYMPTOMVERSION2  611032 non-null  float64
#  5   SYMPTOM3         469883 non-null  object
#  6   SYMPTOMVERSION3  469883 non-null  float64
#  7   SYMPTOM4         353940 non-null  object
#  8   SYMPTOMVERSION4  353940 non-null  float64
#  9   SYMPTOM5         260847 non-null  object
#  10  SYMPTOMVERSION5  260847 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 71.3+ MB

# %%
df_vaers_vax
# Out:
#        VAERS_ID VAX_TYPE          VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0        916600  COVID19           MODERNA  037K20A               1        IM
# 1        916601  COVID19           MODERNA  025L20A               1        IM
# 2        916602  COVID19   PFIZER\BIONTECH   EL1284               1        IM
# 3        916603  COVID19           MODERNA  unknown             UNK       NaN
# 4        916604  COVID19           MODERNA      NaN               1        IM
# ...         ...      ...               ...      ...             ...       ...
# 60143    918503  COVID19           MODERNA  039K20A               1        IM
# 60144    918512      MMR  MERCK & CO. INC.  S029457               1        SC
# 60145    918512    PNC13      PFIZER\WYETH   DJ7723               4        IM
# 60146    918512   VARCEL  MERCK & CO. INC.  T020652               1        SC
# 60147    918561  COVID19   PFIZER\BIONTECH   EJ1685               1        IM
#
# ...

# %%
df_vaers_vax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 620484 entries, 0 to 60147
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         620484 non-null  int64
#  1   VAX_TYPE         620484 non-null  object
#  2   VAX_MANU         620484 non-null  object
#  3   VAX_LOT          425027 non-null  object
#  4   VAX_DOSE_SERIES  616622 non-null  object
#  5   VAX_ROUTE        484392 non-null  object
#  6   VAX_SITE         456292 non-null  object
#  7   VAX_NAME         620484 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 42.6+ MB

# %%
df_merge_vaers = pd.merge(left=df_vaers_data,right=df_vaers_symptoms,on='VAERS_ID')
df_merge_vaers = pd.merge(left=df_merge_vaers,right=df_vaers_vax,on='VAERS_ID')
df_merge_vaers
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0         916600    1/1/2021    TX     33.0     33.0      NaN   F      NaN
# 1         916601    1/1/2021    CA     73.0     73.0      NaN   F      NaN
# 2         916602    1/1/2021    WA     23.0     23.0      NaN   F      NaN
# 3         916603    1/1/2021    WA     58.0     58.0      NaN   F      NaN
# 4         916604    1/1/2021    TX     47.0     47.0      NaN   F      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 825185    918503  12/31/2020    RI     50.0     50.0      NaN   F      NaN
# 825186    918512  12/31/2020    OR      1.0      1.0      0.0   M      NaN
# 825187    918512  12/31/2020    OR      1.0      1.0      0.0   M      NaN
# 825188    918512  12/31/2020    OR      1.0      1.0      0.0   M      NaN
# 825189    918561  12/31/2020    WA     95.0     95.0      NaN   F      NaN
#
# ...

# %%
df_merge_vaers.shape
# Out:
# (825190, 52)

# %%
df_merge_vaers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 825190 entries, 0 to 825189
# Data columns (total 52 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         825190 non-null  int64
#  1   RECVDATE         825190 non-null  object
#  2   STATE            737801 non-null  object
#  3   AGE_YRS          747933 non-null  float64
#  4   CAGE_YR          683795 non-null  float64
#  5   CAGE_MO          10420 non-null   float64
#  6   SEX              825190 non-null  object
#  7   RPT_DATE         2074 non-null    object
#  8   SYMPTOM_TEXT     825049 non-null  object
#  9   DIED             12260 non-null   object
#  10  DATEDIED         11306 non-null   object
#  11  L_THREAT         20507 non-null   object
#  12  ER_VISIT         415 non-null     object
#  13  HOSPITAL         72673 non-null   object
#  14  HOSPDAYS         52518 non-null   float64
#  15  X_STAY           723 non-null     object
# ...

# %%
df_merge_vaers.head()
# Out:
#    VAERS_ID  RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916600  1/1/2021    TX     33.0     33.0      NaN   F      NaN
# 1    916601  1/1/2021    CA     73.0     73.0      NaN   F      NaN
# 2    916602  1/1/2021    WA     23.0     23.0      NaN   F      NaN
# 3    916603  1/1/2021    WA     58.0     58.0      NaN   F      NaN
# 4    916604  1/1/2021    TX     47.0     47.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Right side of epiglottis swelled up and hinder...  NaN  ...
# 1  Approximately 30 min post vaccination administ...  NaN  ...
# 2  About 15 minutes after receiving the vaccine, ...  NaN  ...
# 3  extreme fatigue, dizziness,. could not lift my...  NaN  ...
# 4  Injection site swelling, redness, warm to the ...  NaN  ...
#
#   SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5 VAX_TYPE         VAX_MANU  VAX_LOT  \
# 0             NaN      NaN             NaN  COVID19          MODERNA  037K20A
# ...

# %%
df_merge_vaers.tail()
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 825185    918503  12/31/2020    RI     50.0     50.0      NaN   F      NaN
# 825186    918512  12/31/2020    OR      1.0      1.0      0.0   M      NaN
# 825187    918512  12/31/2020    OR      1.0      1.0      0.0   M      NaN
# 825188    918512  12/31/2020    OR      1.0      1.0      0.0   M      NaN
# 825189    918561  12/31/2020    WA     95.0     95.0      NaN   F      NaN
#
#                                              SYMPTOM_TEXT DIED  ...  \
# 825185  Nausea, tightness in chest from nausea  BP  10...  NaN  ...
# 825186  10 days after vaccines, developed hives & indu...  NaN  ...
# 825187  10 days after vaccines, developed hives & indu...  NaN  ...
# 825188  10 days after vaccines, developed hives & indu...  NaN  ...
# 825189  Report of awakening with difficulty concentrat...  NaN  ...
#
#        SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5 VAX_TYPE          VAX_MANU  \
# ...

# %%
df_merge_vaers.drop(['RPT_DATE', 'ER_VISIT','FORM_VERS','SPLTTYPE','CAGE_YR','CAGE_MO','V_FUNDBY','VAX_SITE','VAX_DOSE_SERIES','VAX_LOT','V_ADMINBY'],axis='columns',inplace=True)
df_merge_vaers.shape
# Out:
# (825190, 41)

# %%
df_merge_vaers.VAX_TYPE.unique()
# Out:
# array(['COVID19', 'FLUC4', 'UNK', 'FLU4', 'PPV', 'FLUA3', 'VARZOS',
#        'DTAPHEPBIP', 'HIBV', 'RV1', 'HPV9', 'DTAP', 'MMRV', 'TDAP',
#        'FLUR4', 'PNC13', 'YF', 'FLUX', 'HEP', 'FLUA4', 'FLUC3', 'HEPA',
#        'HPV4', 'MMR', 'MENB', 'FLUN4', 'DTAPIPV', 'ADEN_4_7', 'ANTH',
#        'VARCEL', 'RV5', 'CHOL', 'DT', 'TTOX', 'FLU3', 'MNQ', 'DTAPIPVHIB',
#        'EBZR', 'IPV', 'TYP', 'DF', 'HPVX', 'TD', 'FLUX(H1N1)', 'RVX',
#        'HEPAB', 'MENHIB', 'DTP', 'JEV1', 'FLU(H1N1)', 'RAB', 'PNC', 'MEN',
#        'MNQHIB', 'OPV', 'SMALL', 'FLUN3', '6VAX-F', 'PNC10', 'FLUR3',
#        'HPV2', 'BCG', 'JEVX', 'DTOX', 'HBHEPB', 'RUB'], dtype=object)

# %%
len(df_merge_vaers[df_merge_vaers['VAX_TYPE'] != 'COVID19'])
# Out:
# 77770

# %%
df_merge_vaers.shape[0] - len(df_merge_vaers[df_merge_vaers['VAX_TYPE'] != 'COVID19'])
# Out:
# 747420

# %%
df_merge_vaers.drop(df_merge_vaers[df_merge_vaers.VAX_TYPE != 'COVID19'].index, inplace=True )

# %%
df_merge_vaers.shape[0]
# Out:
# 747420

# %%
df_merge_vaers.VAX_TYPE.unique()
# Out:
# array(['COVID19'], dtype=object)

# %%
df_merge_vaers.head()
# Out:
#    VAERS_ID  RECVDATE STATE  AGE_YRS SEX  \
# 0    916600  1/1/2021    TX     33.0   F
# 1    916601  1/1/2021    CA     73.0   F
# 2    916602  1/1/2021    WA     23.0   F
# 3    916603  1/1/2021    WA     58.0   F
# 4    916604  1/1/2021    TX     47.0   F
#
#                                         SYMPTOM_TEXT DIED DATEDIED L_THREAT  \
# 0  Right side of epiglottis swelled up and hinder...  NaN      NaN      NaN
# 1  Approximately 30 min post vaccination administ...  NaN      NaN      NaN
# 2  About 15 minutes after receiving the vaccine, ...  NaN      NaN      NaN
# 3  extreme fatigue, dizziness,. could not lift my...  NaN      NaN      NaN
# 4  Injection site swelling, redness, warm to the ...  NaN      NaN      NaN
#
#   HOSPITAL  ...                 SYMPTOM3 SYMPTOMVERSION3  \
# 0      NaN  ...                      NaN             NaN
# 1      NaN  ...                      NaN             NaN
# 2      NaN  ...        Pain in extremity            23.1
# ...

# %%
df_merge_vaers["RECVDATE"] = pd.to_datetime(df_merge_vaers["RECVDATE"])
df_merge_vaers = df_merge_vaers.sort_values(by='RECVDATE')
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ     56.0   F
# 808126    902557 2020-12-15    AK     32.0   F
# 808124    902524 2020-12-15    NE     59.0   F
# 808123    902524 2020-12-15    NE     59.0   F
# 808113    902518 2020-12-15    IN     58.0   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...  NaN      NaN
# 808126  1750- IM injection ot R Deltoid.  She was sitt...  NaN      NaN
# 808124  I am a immunization nurse at this location.  I...  NaN      NaN
# 808123  I am a immunization nurse at this location.  I...  NaN      NaN
# 808113  Tingling of upper lip and cheeks, warmth in fa...  NaN      NaN
#
#        L_THREAT HOSPITAL  ...          SYMPTOM3 SYMPTOMVERSION3  \
# 807983      NaN      NaN  ...               NaN             NaN
# 808126      NaN      NaN  ...     Tunnel vision            23.1
# ...

# %%
df_merge_vaers.DIED.unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
df_merge_vaers['DIED'] = df_merge_vaers['DIED'].fillna('N')
df_merge_vaers['DATEDIED'] = df_merge_vaers['DATEDIED'].fillna('NA')
df_merge_vaers['L_THREAT'] = df_merge_vaers['L_THREAT'].fillna('N')
df_merge_vaers['HOSPITAL'] = df_merge_vaers['HOSPITAL'].fillna('N')

# %%
df_merge_vaers.DIED.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ     56.0   F
# 808126    902557 2020-12-15    AK     32.0   F
# 808124    902524 2020-12-15    NE     59.0   F
# 808123    902524 2020-12-15    NE     59.0   F
# 808113    902518 2020-12-15    IN     58.0   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  ...          SYMPTOM3 SYMPTOMVERSION3  \
# 807983        N        N  ...               NaN             NaN
# 808126        N        N  ...     Tunnel vision            23.1
# ...

# %%
df_merge_vaers.SEX.unique()
# Out:
# array(['F', 'M', 'U'], dtype=object)

# %%
len(df_merge_vaers[df_merge_vaers['SEX'] == 'U'])
# Out:
# 19214

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.float_format",lambda x:'%.2f'%x)
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N       NaN    NaN     NaN      Y  12/15/2020
# 808126        N        N       NaN    NaN     NaN      U  12/15/2020
# ...

# %%
df_merge_vaers.drop_duplicates(subset=None,keep='first',inplace=True)

# %%
df_merge_vaers.shape
# Out:
# (721435, 41)

# %%
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N       NaN    NaN     NaN      Y  12/15/2020
# 808126        N        N       NaN    NaN     NaN      U  12/15/2020
# ...

# %%
df_merge_vaers.HOSPDAYS.unique()
# Out:
# array([       nan, 1.0000e+00, 2.0000e+00, 3.0000e+00, 4.0000e+00,
#        6.0000e+00, 9.0000e+00, 7.0000e+00, 5.0000e+00, 1.1000e+01,
#        1.0000e+01, 8.0000e+00, 1.4000e+01, 1.5000e+01, 2.2000e+01,
#        1.6000e+01, 1.3000e+01, 1.7000e+01, 1.2000e+01, 2.0000e+01,
#        2.1000e+01, 2.6000e+01, 2.4000e+01, 3.6000e+01, 1.9000e+01,
#        2.5000e+01, 1.8000e+01, 2.7000e+01, 2.9000e+01, 3.9000e+01,
#        2.8000e+01, 3.3000e+01, 3.8000e+01, 3.7000e+01, 3.0000e+01,
#        4.3000e+01, 4.2000e+01, 4.0000e+01, 3.4000e+01, 3.2000e+01,
#        2.3000e+01, 3.1000e+01, 9.0000e+01, 5.5000e+01, 5.0000e+01,
#        3.5000e+01, 4.5000e+01, 9.9900e+02, 5.1000e+01, 4.4000e+01,
#        4.1000e+01, 4.7000e+01, 1.0400e+02, 6.5000e+01, 6.8000e+01,
#        5.9000e+01, 5.4000e+01, 6.0000e+01, 8.0000e+01, 9.9999e+04,
#        7.8000e+01, 6.3000e+01, 8.2000e+01, 9.5000e+01, 9.1000e+01,
#        5.7000e+01, 9.7000e+01, 1.2000e+02, 7.4000e+01, 9.2000e+01,
# ...

# %%
df_merge_vaers['HOSPDAYS'] = df_merge_vaers.HOSPDAYS.fillna(0)

# %%
df_merge_vaers.HOSPDAYS.unique()
# Out:
# array([0.0000e+00, 1.0000e+00, 2.0000e+00, 3.0000e+00, 4.0000e+00,
#        6.0000e+00, 9.0000e+00, 7.0000e+00, 5.0000e+00, 1.1000e+01,
#        1.0000e+01, 8.0000e+00, 1.4000e+01, 1.5000e+01, 2.2000e+01,
#        1.6000e+01, 1.3000e+01, 1.7000e+01, 1.2000e+01, 2.0000e+01,
#        2.1000e+01, 2.6000e+01, 2.4000e+01, 3.6000e+01, 1.9000e+01,
#        2.5000e+01, 1.8000e+01, 2.7000e+01, 2.9000e+01, 3.9000e+01,
#        2.8000e+01, 3.3000e+01, 3.8000e+01, 3.7000e+01, 3.0000e+01,
#        4.3000e+01, 4.2000e+01, 4.0000e+01, 3.4000e+01, 3.2000e+01,
#        2.3000e+01, 3.1000e+01, 9.0000e+01, 5.5000e+01, 5.0000e+01,
#        3.5000e+01, 4.5000e+01, 9.9900e+02, 5.1000e+01, 4.4000e+01,
#        4.1000e+01, 4.7000e+01, 1.0400e+02, 6.5000e+01, 6.8000e+01,
#        5.9000e+01, 5.4000e+01, 6.0000e+01, 8.0000e+01, 9.9999e+04,
#        7.8000e+01, 6.3000e+01, 8.2000e+01, 9.5000e+01, 9.1000e+01,
#        5.7000e+01, 9.7000e+01, 1.2000e+02, 7.4000e+01, 9.2000e+01,
# ...

# %%
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N      0.00    NaN     NaN      Y  12/15/2020
# 808126        N        N      0.00    NaN     NaN      U  12/15/2020
# ...

# %%
df_merge_vaers.X_STAY.unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
df_merge_vaers['X_STAY'] = df_merge_vaers.X_STAY.fillna('N')

# %%
df_merge_vaers.X_STAY.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N      0.00      N     NaN      Y  12/15/2020
# 808126        N        N      0.00      N     NaN      U  12/15/2020
# ...

# %%
df_merge_vaers.DISABLE.unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
df_merge_vaers['DISABLE'] = df_merge_vaers.X_STAY.fillna('N')

# %%
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N      0.00      N       N      Y  12/15/2020
# 808126        N        N      0.00      N       N      U  12/15/2020
# ...

# %%
df_merge_vaers['DISABLE'] = df_merge_vaers.X_STAY.fillna('N')

# %%
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N      0.00      N       N      Y  12/15/2020
# 808126        N        N      0.00      N       N      U  12/15/2020
# ...

# %%
df_merge_vaers.RECOVD.unique()
# Out:
# array(['Y', 'U', nan, 'N'], dtype=object)

# %%
print("Unknown :- ",len(df_merge_vaers[df_merge_vaers['RECOVD'] == 'U']))
print("NaN :- ", df_merge_vaers['RECOVD'].isnull().sum())
# Out:
# Unknown :-  150619
# NaN :-  54806

# %% [markdown]
# The RECOVD Column in the dataframe contains information about the status of patients recovery.
# * Y -> recovered
# * N -> Not recovered
# * U -> Unknown (count :- 150619)
# * NaN -> field is left blank (count :- 54806)

# %%
print("NaN values in AGE field :- ", df_merge_vaers['AGE_YRS'].isnull().sum())
# Out:
# NaN values in AGE field :-  58451

# %% [markdown]
# In the AGE_YRS columns there are many filed which are NaN (Blank) :- 58451.
# * Remedy Fill NaN fileds with mean age.

# %%
print("NaN values in Symptoms field :- ", df_merge_vaers['SYMPTOM_TEXT'].isnull().sum())
# Out:
# NaN values in Symptoms field :-  126

# %% [markdown]
# As there are only 126 fields in symptoms column which are blank it is ok to delete such fields.

# %%
df_merge_vaers.dropna(subset=["SYMPTOM_TEXT"], inplace=True)
print("NaN values in Symptoms field :- ", df_merge_vaers['SYMPTOM_TEXT'].isnull().sum())
df_merge_vaers.head()
# Out:
# NaN values in Symptoms field :-  0
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N      0.00      N       N      Y  12/15/2020
# ...

# %%
df_merge_vaers.LAB_DATA.unique()
# Out:
# array(['none', 'ED visit, blood draw, monitoring - 12/15/20', nan, ...,
#        'Ct scan - negative for stroke.',
#        'skin biopsy confirming bullous pemphigoid.',
#        'Test Name: Blood cholesterol; Result Unstructured Data: Test Result:abnormal; Test Name: COVID-19 virus test; Test Result: Positive  ; Test Name: Vitamin D; Result Unstructured Data: Test Result:deficiency'],
#       dtype=object)

# %%
print("NaN values in LAB Data field :- ", df_merge_vaers['LAB_DATA'].isnull().sum())
# Out:
# NaN values in LAB Data field :-  389034

# %%
df_merge_vaers['LAB_DATA'] = df_merge_vaers['LAB_DATA'].fillna('none')
print("NaN values in LAB Data field :- ", df_merge_vaers['LAB_DATA'].isnull().sum())
# Out:
# NaN values in LAB Data field :-  0

# %%
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N      0.00      N       N      Y  12/15/2020
# 808126        N        N      0.00      N       N      U  12/15/2020
# ...

# %%
df_merge_vaers.PRIOR_VAX.unique()
# Out:
# array([nan,
#        'vaso-vagal type symptoms, similar presentation 12 hours post vaccine',
#        'Tetanus shot. Near death experience. Saw tunnel, white light, passed relatives, God. Transient neurological problem lasting abou',
#        ..., 'Thimerosal containing vaccines',
#        'All vaccination gives her mild pains',
#        'Pertussis at 1 year- 1981'], dtype=object)

# %%
df_merge_vaers['OTHER_MEDS'] = df_merge_vaers['OTHER_MEDS'].fillna('none')
df_merge_vaers['CUR_ILL'] = df_merge_vaers['CUR_ILL'].fillna('none')
df_merge_vaers['HISTORY'] = df_merge_vaers['HISTORY'].fillna('none')
df_merge_vaers['PRIOR_VAX'] = df_merge_vaers['PRIOR_VAX'].fillna('none')
df_merge_vaers['BIRTH_DEFECT'] = df_merge_vaers['BIRTH_DEFECT'].fillna('N')
df_merge_vaers['OFC_VISIT'] = df_merge_vaers['OFC_VISIT'].fillna('N')
df_merge_vaers['ER_ED_VISIT'] = df_merge_vaers['ER_ED_VISIT'].fillna('N')
df_merge_vaers['VAX_ROUTE'] = df_merge_vaers['VAX_ROUTE'].fillna('IM')
df_merge_vaers['ALLERGIES'] = df_merge_vaers['ALLERGIES'].fillna('none')

# %%
print(df_merge_vaers.shape)
df_merge_vaers.head()
# Out:
# (721309, 41)
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N      0.00      N       N      Y  12/15/2020
# 808126        N        N      0.00      N       N      U  12/15/2020
# ...

# %%
df_merge_vaers.SYMPTOM1.unique()
# Out:
# array(['Hypoaesthesia', 'Hyperhidrosis', 'Impaired driving ability', ...,
#        'Colon neoplasm', 'Ovarian clear cell carcinoma',
#        'Myelosuppression'], dtype=object)

# %%
print("NaN values in SYMPTOM1 field :- ", df_merge_vaers['SYMPTOM1'].isnull().sum())
print("NaN values in SYMPTOMVERSION1 field :- ", df_merge_vaers['SYMPTOMVERSION1'].isnull().sum())
print("NaN values in SYMPTOM2 field :- ", df_merge_vaers['SYMPTOM2'].isnull().sum())
print("NaN values in SYMPTOMVERSION2 field :- ", df_merge_vaers['SYMPTOMVERSION2'].isnull().sum())
print("NaN values in SYMPTOM3 field :- ", df_merge_vaers['SYMPTOM3'].isnull().sum())
print("NaN values in SYMPTOMVERSION3 field :- ", df_merge_vaers['SYMPTOMVERSION3'].isnull().sum())
print("NaN values in SYMPTOM4 field :- ", df_merge_vaers['SYMPTOM4'].isnull().sum())
print("NaN values in SYMPTOMVERSION4 field :- ", df_merge_vaers['SYMPTOMVERSION4'].isnull().sum())
print("NaN values in SYMPTOM5 field :- ", df_merge_vaers['SYMPTOM5'].isnull().sum())
print("NaN values in SYMPTOMVERSION5 field :- ", df_merge_vaers['SYMPTOMVERSION5'].isnull().sum())
print("NaN values in VAX_MANU field :- ", df_merge_vaers['VAX_MANU'].isnull().sum())
print("NaN values in VAX_ROUTE field :- ", df_merge_vaers['VAX_ROUTE'].isnull().sum())
print("NaN values in VAX_NAME field :- ", df_merge_vaers['VAX_NAME'].isnull().sum())
# Out:
# NaN values in SYMPTOM1 field :-  0
# NaN values in SYMPTOMVERSION1 field :-  0
# NaN values in SYMPTOM2 field :-  153074
# NaN values in SYMPTOMVERSION2 field :-  153074
# NaN values in SYMPTOM3 field :-  280201
# NaN values in SYMPTOMVERSION3 field :-  280201
# NaN values in SYMPTOM4 field :-  387775
# NaN values in SYMPTOMVERSION4 field :-  387775
# NaN values in SYMPTOM5 field :-  474692
# NaN values in SYMPTOMVERSION5 field :-  474692
# NaN values in VAX_MANU field :-  0
# NaN values in VAX_ROUTE field :-  0
# NaN values in VAX_NAME field :-  0

# %%
df_merge_vaers['SYMPTOM2'] = df_merge_vaers['SYMPTOM2'].fillna('none')
df_merge_vaers['SYMPTOMVERSION2'] = df_merge_vaers['SYMPTOMVERSION2'].fillna('none')
df_merge_vaers['SYMPTOM3'] = df_merge_vaers['SYMPTOM3'].fillna('none')
df_merge_vaers['SYMPTOMVERSION3'] = df_merge_vaers['SYMPTOMVERSION3'].fillna('none')
df_merge_vaers['SYMPTOM4'] = df_merge_vaers['SYMPTOM4'].fillna('none')
df_merge_vaers['SYMPTOMVERSION4'] = df_merge_vaers['SYMPTOMVERSION4'].fillna('none')
df_merge_vaers['SYMPTOM5'] = df_merge_vaers['SYMPTOM5'].fillna('none')
df_merge_vaers['SYMPTOMVERSION5'] = df_merge_vaers['SYMPTOMVERSION5'].fillna('none')

# %%
print("NaN values in SYMPTOM1 field :- ", df_merge_vaers['SYMPTOM1'].isnull().sum())
print("NaN values in SYMPTOMVERSION1 field :- ", df_merge_vaers['SYMPTOMVERSION1'].isnull().sum())
print("NaN values in SYMPTOM2 field :- ", df_merge_vaers['SYMPTOM2'].isnull().sum())
print("NaN values in SYMPTOMVERSION2 field :- ", df_merge_vaers['SYMPTOMVERSION2'].isnull().sum())
print("NaN values in SYMPTOM3 field :- ", df_merge_vaers['SYMPTOM3'].isnull().sum())
print("NaN values in SYMPTOMVERSION3 field :- ", df_merge_vaers['SYMPTOMVERSION3'].isnull().sum())
print("NaN values in SYMPTOM4 field :- ", df_merge_vaers['SYMPTOM4'].isnull().sum())
print("NaN values in SYMPTOMVERSION4 field :- ", df_merge_vaers['SYMPTOMVERSION4'].isnull().sum())
print("NaN values in SYMPTOM5 field :- ", df_merge_vaers['SYMPTOM5'].isnull().sum())
print("NaN values in SYMPTOMVERSION5 field :- ", df_merge_vaers['SYMPTOMVERSION5'].isnull().sum())
print("NaN values in VAX_MANU field :- ", df_merge_vaers['VAX_MANU'].isnull().sum())
print("NaN values in VAX_ROUTE field :- ", df_merge_vaers['VAX_ROUTE'].isnull().sum())
print("NaN values in VAX_NAME field :- ", df_merge_vaers['VAX_NAME'].isnull().sum())
# Out:
# NaN values in SYMPTOM1 field :-  0
# NaN values in SYMPTOMVERSION1 field :-  0
# NaN values in SYMPTOM2 field :-  0
# NaN values in SYMPTOMVERSION2 field :-  0
# NaN values in SYMPTOM3 field :-  0
# NaN values in SYMPTOMVERSION3 field :-  0
# NaN values in SYMPTOM4 field :-  0
# NaN values in SYMPTOMVERSION4 field :-  0
# NaN values in SYMPTOM5 field :-  0
# NaN values in SYMPTOMVERSION5 field :-  0
# NaN values in VAX_MANU field :-  0
# NaN values in VAX_ROUTE field :-  0
# NaN values in VAX_NAME field :-  0

# %%
df_merge_vaers.head()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 807983    902418 2020-12-15    NJ    56.00   F
# 808126    902557 2020-12-15    AK    32.00   F
# 808124    902524 2020-12-15    NE    59.00   F
# 808123    902524 2020-12-15    NE    59.00   F
# 808113    902518 2020-12-15    IN    58.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 807983  Patient experienced mild numbness traveling fr...    N       NA
# 808126  1750- IM injection ot R Deltoid.  She was sitt...    N       NA
# 808124  I am a immunization nurse at this location.  I...    N       NA
# 808123  I am a immunization nurse at this location.  I...    N       NA
# 808113  Tingling of upper lip and cheeks, warmth in fa...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 807983        N        N      0.00      N       N      Y  12/15/2020
# 808126        N        N      0.00      N       N      U  12/15/2020
# ...

# %%
df_merge_vaers.tail()
# Out:
#         VAERS_ID   RECVDATE STATE  AGE_YRS SEX  \
# 750994   1669568 2021-09-03    MO      NaN   M
# 750995   1669573 2021-09-03   NaN      NaN   U
# 750996   1669577 2021-09-03   NaN      NaN   U
# 750983   1669185 2021-09-03    PR    58.00   F
# 750976   1667911 2021-09-03    OH    84.00   F
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 750994  SUSPECTED IMMUNOLOGICAL VACCINE FAILURE; This ...    N       NA
# 750995  BLOOD CLOT; This spontaneous report received f...    N       NA
# 750996  DEATH; This spontaneous report received from a...    Y       NA
# 750983  Constant cough; Itching and swelling of the ey...    N       NA
# 750976  8/16/21: COVID pos presented to ED with cough,...    N       NA
#
#        L_THREAT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD   VAX_DATE  \
# 750994        N        N      0.00      N       N      U        NaN
# 750995        N        N      0.00      N       N      U        NaN
# ...

# %%
print("NaN values in VAX_DATE field :- ", df_merge_vaers['VAX_DATE'].isnull().sum())
print("NaN values in ONSET_DATE field :- ", df_merge_vaers['ONSET_DATE'].isnull().sum())
print("NaN values in NUMDAYS field :- ", df_merge_vaers['NUMDAYS'].isnull().sum())
print("NaN values in AGE_YRS field :- ", df_merge_vaers['AGE_YRS'].isnull().sum())
# Out:
# NaN values in VAX_DATE field :-  40058
# NaN values in ONSET_DATE field :-  42358
# NaN values in NUMDAYS field :-  70150
# NaN values in AGE_YRS field :-  58451

# %%
df_merge_vaers.to_csv('C:\\Users\\NIKHIL\\Desktop\\CERELABS\\final_vaers')
